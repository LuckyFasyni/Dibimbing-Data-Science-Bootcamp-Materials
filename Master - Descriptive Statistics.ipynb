# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('HR_comma_sep.csv')

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df.select_dtypes('object').describe()
# Out:
#         sales salary
# count   14999  14999
# unique     10      3
# top     sales    low
# freq     4140   7316

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# # Visualisasi

# %% [markdown]
# ## Histogram

# %%
sns.displot(df['satisfaction_level'])

# %% [markdown]
# ## Barchart

# %%
count_salary = df['salary'].value_counts().reset_index()

sns.barplot(x=count_salary['index'],y=count_salary['salary'])
plt.show()

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(x=df['left'] ,y=df['satisfaction_level'])
plt.show()

# %% [markdown]
# ## Challenge #1
#  1. tampilkan histogram dan boxplot untuk kolom time_spent_company
#  2. tampilkan barchart untuk sales (occupation)

# %% [markdown]
# # Measure of Central Tendency

# %%
sat_mean = df['satisfaction_level'].mean()
sat_median = df['satisfaction_level'].median()
sat_mode = df['satisfaction_level'].mode()[0]

# %%
print('Mean:',sat_mean)
print('Median:',sat_median)
print('Mode:',sat_mode)
# Out:
# Mean: 0.6128335222348166
# Median: 0.64
# Mode: 0.1

# %% [markdown]
# ## Challenge #2
# Keluarkan nilai-nilai statistika deskriptif untuk kolom last_evaluation dan number of project tampilkan histogramnya juga

# %% [markdown]
# # Measure of Spread

# %%
sat_var = df['satisfaction_level'].var()
sat_sd = df['satisfaction_level'].std()
sat_sd_sqrt = np.sqrt(df['satisfaction_level'].var())

# %%
print('Variance:',sat_var)
print('Standard Deviation:',sat_sd)
print('Standard Deviation (Variance Square Root):',sat_sd_sqrt)
# Out:
# Variance: 0.061817200647087255
# Standard Deviation: 0.2486306510611418
# Standard Deviation (Variance Square Root): 0.2486306510611418

# %% [markdown]
# # Bivariate

# %%
sns.scatterplot(df['average_montly_hours'],df['last_evaluation'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Covariance

# %%
df.cov()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               0.061817         0.004469       -0.043814
# last_evaluation                  0.004469         0.029299        0.073703
# number_project                  -0.043814         0.073703        1.519284
# average_montly_hours            -0.248945         2.904356       25.683271
# time_spend_company              -0.036618         0.032888        0.354166
# Work_accident                    0.005133        -0.000428       -0.002055
# left                            -0.041128         0.000479        0.012488
# promotion_last_5years            0.000919        -0.000214       -0.001078
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.248945           -0.036618
# last_evaluation                    2.904356            0.032888
# number_project                    25.683271            0.354166
# ...

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
## Pearson
df[['average_montly_hours','last_evaluation']].corr()
# Out:
#                       average_montly_hours  last_evaluation
# average_montly_hours              1.000000         0.339742
# last_evaluation                   0.339742         1.000000

# %%
## Spearman
df[['average_montly_hours','last_evaluation']].corr(method='spearman')
# Out:
#                       average_montly_hours  last_evaluation
# average_montly_hours              1.000000         0.342061
# last_evaluation                   0.342061         1.000000

# %% [markdown]
# ## Pakai Data IRIS

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris(as_frame=True)
df_iris = iris['data']

# %%
df_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
sns.scatterplot(x=df_iris['sepal length (cm)'],y=df_iris['petal length (cm)'])
plt.show()

# %%
## Pearson
df_iris[['sepal length (cm)','petal length (cm)']].corr()
# Out:
#                    sepal length (cm)  petal length (cm)
# sepal length (cm)           1.000000           0.871754
# petal length (cm)           0.871754           1.000000

# %%
df_iris.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
sns.heatmap(df_iris.corr(),annot=True)
plt.show()

# %% [markdown]
# # - THE END -
